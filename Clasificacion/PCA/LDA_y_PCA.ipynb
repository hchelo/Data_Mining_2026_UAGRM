# %%
# PCA y LDA for Iris DataSet
# Editado por MSaavedra

# %%
# PCA for Iris DataSet
# Editado por MSaavedra
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# Cargar el conjunto de datos de los lirios
iris = load_iris()
X = iris.data
y = iris.target

# Aplicar PCA para reducir la dimensionalidad a 2 componentes
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Crear un gráfico de dispersión para visualizar los resultados en 2D
plt.figure(figsize=(8, 6))
colors = ['navy', 'turquoise', 'darkorange']
lw = 2

for color, i, target_name in zip(colors, [0, 1, 2], iris.target_names):
    plt.scatter(X_pca[y == i, 0], X_pca[y == i, 1], alpha=.8, color=color,
                label=target_name, linewidths=lw)
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA of Iris dataset')

plt.show()

# %%
# PCA y LDA for Iris DataSet
# Editado por MSaavedra

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# Cargar el conjunto de datos de los lirios
iris = load_iris()
X = iris.data
y = iris.target

#print(X)

# %%
# Aplicar LDA para reducir la dimensionalidad a 2 dimensiones
lda = LDA(n_components=2)
X_lda = lda.fit_transform(X, y)

# Crear un gráfico de dispersión para visualizar los resultados en 2D
plt.figure(figsize=(8, 6))
colors = ['navy', 'turquoise', 'darkorange']
lw = 2

for color, i, target_name in zip(colors, [0, 1, 2], iris.target_names):
    plt.scatter(X_lda[y == i, 0], X_lda[y == i, 1], alpha=.8, color=color,
                label=target_name, linewidths=lw)
plt.xlabel('LDA Component 1')
plt.ylabel('LDA Component 2')
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('LDA of Iris dataset')

plt.show()
